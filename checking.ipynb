# %%
import pandas as pd
df = pd.read_csv('test2.csv')
df
# Out:
#     GPAX                   EntryTypeName  Q1  Q2  Q3  Q4  Q5  Q6  Q23  Q24  \
# 0   3.61     QUOTA 17 NORTHERN PROVINCES   1   1   1   1   1   1    0    0
# 1   3.92      DIRECT ADMISSION BY SCHOOL   1   1   1   1   1   1    0    0
# 2   3.60                DIRECT ADMISSION   1   1   0   0   1   1    0    0
# 3   3.23        SPECIAL FOR GOOD STUDENT   0   0   0   1   0   1    0    0
# 4   0.00            INTERNATIONAL SCHOOL   1   0   1   1   1   0    1    1
# 5   3.48            GOOD BEHAVE STUDENTS   1   1   1   1   1   1    1    1
# 6   3.17                  EP-MEP PROGRAM   1   1   1   1   1   1    1    1
# 7   2.90                 QUOTA BY SCHOOL   1   1   1   0   0   0    0    0
# 8   3.04  RE-ID FIRST SEMESTER GPAX 2.00   0   0   0   0   1   0    0    0
# 9   3.16                  SPECIAL TALENT   0   1   1   0   0   0    0    0
# 10  3.19      DIRECT ADMISSION BY SCHOOL   1   1   1   1   1   1    0    1
# ...

# %%
df.EntryTypeName.unique()
# Out:
# array(['QUOTA 17 NORTHERN PROVINCES', 'DIRECT ADMISSION BY SCHOOL',
#        'DIRECT ADMISSION', 'SPECIAL FOR GOOD STUDENT',
#        'INTERNATIONAL SCHOOL', 'GOOD BEHAVE STUDENTS', 'EP-MEP PROGRAM',
#        'QUOTA BY SCHOOL', 'RE-ID FIRST SEMESTER GPAX 2.00',
#        'SPECIAL TALENT', 'DISABLE STUDENT', 'QUOTA FOR SOUTHERN BORDER'],
#       dtype=object)
